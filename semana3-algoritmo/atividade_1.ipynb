# %%
print("Números de andares do Prédio Ocean Drive")
numero_de_andares = 20
for i in range(1,numero_de_andares):
    if i != 13:
      print("Andar {}.".format(i))
# Out:
# Números de andares do Prédio Ocean Drive
# Andar 1.
# Andar 2.
# Andar 3.
# Andar 4.
# Andar 5.
# Andar 6.
# Andar 7.
# Andar 8.
# Andar 9.
# Andar 10.
# Andar 11.
# Andar 12.
# Andar 14.
# Andar 15.
# Andar 16.
# Andar 17.
# Andar 18.
# Andar 19.

# %%
andares = 20

print("Números de andares do Prédio Sequência do Mar")
i = 1
while i <= andares:
    if i != 13:
        print("Andar {}".format(i))
    i += 1
# Out:
# Números de andares do Prédio Sequência do Mar
# Andar 1
# Andar 2
# Andar 3
# Andar 4
# Andar 5
# Andar 6
# Andar 7
# Andar 8
# Andar 9
# Andar 10
# Andar 11
# Andar 12
# Andar 14
# Andar 15
# Andar 16
# Andar 17
# Andar 18
# Andar 19
# Andar 20

# %%
andares = 20

print("Números de andares do Prédio Sequência do Mar")
i = andares
while i >= 1 :
    if i != 13:
        print("Andar {}".format(i))
    i -= 1
# Out:
# Números de andares do Prédio Sequência do Mar
# Andar 20
# Andar 19
# Andar 18
# Andar 17
# Andar 16
# Andar 15
# Andar 14
# Andar 12
# Andar 11
# Andar 10
# Andar 9
# Andar 8
# Andar 7
# Andar 6
# Andar 5
# Andar 4
# Andar 3
# Andar 2
# Andar 1

# %%
print("Números de andares do Prédio Ocean Drive")
numero_de_andares = 20
for i in range(numero_de_andares,0,-1):
    if i != 13:
      print("Andar {}.".format(i))
# Out:
# Números de andares do Prédio Ocean Drive
# Andar 20.
# Andar 19.
# Andar 18.
# Andar 17.
# Andar 16.
# Andar 15.
# Andar 14.
# Andar 12.
# Andar 11.
# Andar 10.
# Andar 9.
# Andar 8.
# Andar 7.
# Andar 6.
# Andar 5.
# Andar 4.
# Andar 3.
# Andar 2.
# Andar 1.
